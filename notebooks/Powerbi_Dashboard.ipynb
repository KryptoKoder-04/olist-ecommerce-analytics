# %% [markdown]
# # 🔥 POWER BI DASHBOARD STRUCTURE

# %% [markdown]
# ## PAGE 1 – EXECUTIVE OVERVIEW

# %% [markdown]
# KPI Cards:
#
# * Revenue
# * Profit
# * Margin %
# * Customers
# * Orders
# * Churn %

# %% [markdown]
# Charts:
#
# * Monthly Revenue Trend
# * Pareto Chart
# * Churn Donut
#
# ---

# %% [markdown]
# ## PAGE 2 – CUSTOMER ANALYTICS

# %% [markdown]
# * RFM Segment Distribution
# * Revenue by Segment
# * CLV Distribution
# * Cohort Heatmap
#
# ---

# %% [markdown]
# ## PAGE 3 – PRODUCT & REGION

# %% [markdown]
# * Category Revenue
# * Category Margin Scatter
# * State Revenue
# * State Margin
# * Freight Impact Scatter
#
# ---
